# %%
import pandas as pd

# %%
df = pd.read_csv('output.csv')

# %%
df.loc[df['username'] == 'kevin-meyers', 'most_used_language'].value_counts()
# Out:
# Python              12
# Jupyter Notebook     6
# HTML                 5
# CSS                  1
# C#                   1
# Name: most_used_language, dtype: int64

# %%
df
# Out:
#         username                             repo_name most_used_language
# 0    ericanaglik    cracking-the-coding-interview-prep         JavaScript
# 1    ericanaglik                          few2.5-final               HTML
# 2    ericanaglik                            pokemon-d3               HTML
# 3    ericanaglik                   data-visualizations               HTML
# 4    ericanaglik               rate-my-courses-backend         JavaScript
# 5    ericanaglik                       rate-my-courses         JavaScript
# 6    ericanaglik                        react-studying         JavaScript
# 7    ericanaglik                     node-reddit-clone         JavaScript
# 8    ericanaglik                  react-router-example                CSS
# 9    ericanaglik                  CS-2.1-Trees-Sorting             Python
# 10   ericanaglik                           js-math-lib               HTML
# 11   ericanaglik                          kevin-string         JavaScript
# ...
